# %%
import pandas as pd

# %%
df = pd.read_csv("mods.txt", sep=',')

# %%
df.head()
# Out:
#    #Mod_Priority #Mod_Status                                #Mod_Name #Note  \
# 0              0           +                         DLC: HearthFires   NaN
# 1              1           +                          DLC: Dragonborn   NaN
# 2              2           +                           DLC: Dawnguard   NaN
# 3              3           +  Creation Club: ccQDRSSE001-SurvivalMode   NaN
# 4              4           +        Creation Club: ccBGSSSE037-Curios   NaN
#
#   #Mod_Nexus_URL #Download_File_Name
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN

# %%
df.drop(["#Mod_Status", "#Note", "#Download_File_Name", "#Mod_Priority"], axis = 1)
# Out:
#                                              #Mod_Name  \
# 0                                     DLC: HearthFires
# 1                                      DLC: Dragonborn
# 2                                       DLC: Dawnguard
# 3              Creation Club: ccQDRSSE001-SurvivalMode
# 4                    Creation Club: ccBGSSSE037-Curios
# ..                                                 ...
# 529       Paarthurnax - Quest Expansion Dublagem PT BR
# 530                               DUBLAGEM 1.6 + FIXES
# 531  DBVO Victoria - Feminino - ESCOLHA APENAS OQUE...
# 532  DBVO sylas - Masculino - ESCOLHA APENAS OQUE V...
# 533                            FRESH INSTALL_separator
#
#                                         #Mod_Nexus_URL
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# ...

# %%
import streamlit as st

# %%
st.title("Mods Skyrim")
st.dataframe(df)
# Out:
# 2026-02-26 08:15:32.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 08:15:32.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 08:15:32.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 08:15:32.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 08:15:32.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-26 08:15:32.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
from IPython.display import display
display(df)
# Out:
#      #Mod_Priority #Mod_Status  \
# 0                0           +
# 1                1           +
# 2                2           +
# 3                3           +
# 4                4           +
# ..             ...         ...
# 529            529           +
# 530            530           +
# 531            531           -
# 532            532           -
# 533            533           -
#
#                                              #Mod_Name #Note  \
# 0                                     DLC: HearthFires   NaN
# 1                                      DLC: Dragonborn   NaN
# 2                                       DLC: Dawnguard   NaN
# 3              Creation Club: ccQDRSSE001-SurvivalMode   NaN
# 4                    Creation Club: ccBGSSSE037-Curios   NaN
# ..                                                 ...   ...
# 529       Paarthurnax - Quest Expansion Dublagem PT BR   NaN
# 530                               DUBLAGEM 1.6 + FIXES   NaN
# ...
